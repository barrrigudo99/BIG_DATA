# %%
operacion = input('que operacion quieres hacer? s,r,m,d ó S ')

while (operacion != 'S'):
  a = float(input('valor de a'))
  b = float(input('valor de b'))

  if (operacion == 's'):
  
    print(a + b)

    operacion = input('dame otra operacion')
# Out:
# que operacion quieres hacer? s,r,m,d ó S s
# valor de a5
# valor de b6
# 11.0
# dame otra operacionS
