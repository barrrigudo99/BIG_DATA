# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# import seaborn as sns
# import plotly as ply

features = pd.read_csv('/content/drive/MyDrive/BIG DATA CURSO/SEMANA 4/Features.csv', sep = '\t') # 

print(type(features))
print(features)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    id,name,duration,energy,key,loudness,mode,speechiness,acousticness,instrumentalness,liveness,valence,tempo,danceability
# 0   0VjIjW4GlUZAMYd2vXMi3b,Blinding Lights,3.33,0....
# 1   7qiZfU4dY1lWllzX7mPBI3,Shape of You,3.9,0.652,...
# 2   2XU0oxnq2qxCpomAAuJY8K,Dance Monkey,3.49,0.588...
# 3   7qEHsqek33rTcFNT9PFqLf,Someone You Loved,3.04,...
# 4   0e7ipj03S05BNilyu5bRzt,Rockstar,3.64,0.52,5,-6...
# ..                                                ...
# 95  5kqIPrATaCc2LqxVWzQGbk,7 Years,3.96,0.473,10,-...
# 96  3AJwUDP919kvQ9QcozQPxg,Yellow,4.45,0.661,11,-7...
# 97  6UelLqGlWMcVH1E5c4H7lY,Sugar,2.9,0.816,0,-4.20...
# 98  6habFhsOp2NvshLv26DqMb,Despacito,3.82,0.797,2,...
# 99  6XdYD0hrNIOHb0emKC3l9U,Don't Stop Me Now,7.05,...
#
# [100 rows x 1 columns]
