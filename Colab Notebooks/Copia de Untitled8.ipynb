# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/BIG DATA - MADRID - PROD50 T5/datasets/Loan-Data.csv')

# %%
tierra = "La;T1eRR@#Es#Red0nD@?"
print(tierra)

T = tierra.replace(';',' ').replace('1','i').replace('RR','rr').replace('@','a').replace('#',' ')

letra_E = tierra[10]
letr_e = letra_E.lower()

#.lower('E')
print(T)
print(letra_E)
print(letra_e)
# Out:
# La;T1eRR@#Es#Red0nD@?
# La Tierra Es Red0nDa?
# E
# E
