# %%
variable_lista = ['carlos, javi, dani']
print(variable_lista)
# Out:
# ['carlos, javi, dani']

# %%
variable_lista = ['carlos, javi, dani']

variable_lista.append('edu').append('fer')

print(variable_lista)
