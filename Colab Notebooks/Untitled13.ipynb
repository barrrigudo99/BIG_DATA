# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/content/drive'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# reading Datasets 
path = '/content/drive/MyDrive/BIG DATA CURSO/practicas py/amazon.csv'
df = pd.read_csv(path)
columnas = df.head()
# columnas['product_id'].count()
columnas.describe()
# Out:
#         product_id                                       product_name  \
# count            5                                                  5
# unique           5                                                  5
# top     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# freq             1                                                  1
#
#                                                  category discounted_price  \
# count                                                   5                5
# unique                                                  1                4
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                    5                2
#
#        actual_price discount_percentage rating rating_count  \
# count             5                   5      5            5
# unique            5                   5      3            5
# top          ₹1,099                 64%    4.2       24,269
# freq              1                   1      3            1
#
#                                             about_product  \
# count                                                   5
# unique                                                  5
# top     High Compatibility : Compatible With iPhone 12...
# freq                                                    1
#
#                                                   user_id  \
# count                                                   5
# unique                                                  5
# top     AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# freq                                                    1
#
#                                                 user_name  \
# count                                                   5
# unique                                                  5
# top     Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# freq                                                    1
#
#                                                 review_id  \
# count                                                   5
# unique                                                  5
# top     R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# freq                                                    1
#
#                                              review_title  \
# count                                                   5
# unique                                                  5
# top     Satisfied,Charging is really fast,Value for mo...
# freq                                                    1
#
#                                            review_content  \
# count                                                   5
# unique                                                  5
# top     Looks durable Charging is fine tooNo complains...
# freq                                                    1
#
#                                                  img_link  \
# count                                                   5
# unique                                                  5
# top     https://m.media-amazon.com/images/W/WEBP_40237...
# freq                                                    1
#
#                                              product_link
# count                                                   5
# unique                                                  5
# top     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# freq                                                    1
