# %%
tamanyo = input('Qué libro te llevas')

if tamanyo == 'pequeño':
  precio = 28.95
elif tamanyo == 'grande':
  precio = 38

sueldo = float(input('Qué cobras'))
if sueldo > 1200:
  descSueldo = 1
else:
  descSueldo = 0.8
  
descSocio = 0.95
print(precio)
precio*descSueldo*descSocio
# Out:
# Qué libro te llevas pequeño
